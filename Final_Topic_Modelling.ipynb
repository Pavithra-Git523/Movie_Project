# %%
# !pip install pandas numpy nltk gensim scikit-learn pyLDAvis spacy
# Out:
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: nltk in c:\users\dell\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: gensim in c:\users\dell\anaconda3\lib\site-packages (4.4.0)
# Requirement already satisfied: scikit-learn in c:\users\dell\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: pyLDAvis in c:\users\dell\anaconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: spacy in c:\users\dell\anaconda3\lib\site-packages (3.8.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: click in c:\users\dell\anaconda3\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\dell\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dell\anaconda3\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\dell\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\dell\anaconda3\lib\site-packages (from gensim) (1.15.3)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\dell\anaconda3\lib\site-packages (from gensim) (7.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\lib\site-packages (from pyLDAvis) (3.1.6)
# Requirement already satisfied: numexpr in c:\users\dell\anaconda3\lib\site-packages (from pyLDAvis) (2.10.1)
# Requirement already satisfied: funcy in c:\users\dell\anaconda3\lib\site-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\lib\site-packages (from pyLDAvis) (72.1.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\dell\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dell\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dell\anaconda3\lib\site-packages (from spacy) (1.0.14)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dell\anaconda3\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dell\anaconda3\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\dell\anaconda3\lib\site-packages (from spacy) (8.3.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\dell\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\dell\anaconda3\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\dell\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\dell\anaconda3\lib\site-packages (from spacy) (0.4.2)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\dell\anaconda3\lib\site-packages (from spacy) (0.20.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\dell\anaconda3\lib\site-packages (from spacy) (2.10.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\dell\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\dell\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\dell\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.2)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\dell\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from tqdm->nltk) (0.4.6)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\dell\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: wrapt in c:\users\dell\anaconda3\lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\lib\site-packages (from jinja2->pyLDAvis) (3.0.2)

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import os
import re
import json
import numpy as np
import pandas as pd

# %%
import pandas as pd

# Replace the file name with dataset path if different
df = pd.read_csv("final_fulldataset_1.csv")

# Check the first few rows
df.head()
# Out:
#    Unnamed: 0       critic_name rotten_tomatoes_link  \
# 0           3      ben mceachen            m/0814255
# 1           6      nick schager            m/0814255
# 2           7  bill goodykoontz            m/0814255
# 3           8    jordan hoffman            m/0814255
# 4           9      jim schembri            m/0814255
#
#                                          movie_title content_rating  \
# 0  percy jackson & the olympians: the lightning t...             pg
# 1  percy jackson & the olympians: the lightning t...             pg
# 2  percy jackson & the olympians: the lightning t...             pg
# 3  percy jackson & the olympians: the lightning t...             pg
# 4  percy jackson & the olympians: the lightning t...             pg
#
#                                               genres  original_release_date  \
# 0  action & adventure, comedy, drama, science fic...                   2010
# 1  action & adventure, comedy, drama, science fic...                   2010
# 2  action & adventure, comedy, drama, science fic...                   2010
# 3  action & adventure, comedy, drama, science fic...                   2010
# 4  action & adventure, comedy, drama, science fic...                   2010
#
#    review_score                                     review_content  \
# 0          70.0  whether audiences will get behind the lightnin...
# 1          25.0  harry potter knockoffs don't come more transpa...
# 2          70.0  percy jackson isn't a great movie, but it's a ...
# 3          83.0                         fun, brisk and imaginative
# 4          60.0  crammed with dragons, set-destroying fights an...
#
#                                           movie_info
# 0  always trouble-prone, the life of teenager per...
# 1  always trouble-prone, the life of teenager per...
# 2  always trouble-prone, the life of teenager per...
# 3  always trouble-prone, the life of teenager per...
# 4  always trouble-prone, the life of teenager per...

# %%
# Aggregate by link, keep title as part of the document and keep link as the ID
df["rotten_tomatoes_link"] = df["rotten_tomatoes_link"].str.strip()
df["combined_review"] =  df["review_content"].fillna("")

reviews_agg = df.groupby("rotten_tomatoes_link").agg({

    "movie_title": lambda x: x.dropna().astype(str).mode().iat[0],
    "original_release_date": lambda x: x.dropna().astype(str).mode().iat[0],
    "movie_info": lambda x: x.dropna().astype(str).mode().iat[0],
    "genres": lambda x: ", ".join(sorted({
        g.strip()
        for g in ",".join(x.dropna().astype(str)).split(",")
        if g.strip()
    })),
    "combined_review": lambda x: " ".join(x.dropna().astype(str))   # moved to last
    
}).reset_index().rename(columns={
    "rotten_tomatoes_link": "movie_link",
    "original_release_date": "year"
})

# ----------------------------------------------
# Reorder columns so combined_review is last
# ----------------------------------------------
cols = [c for c in reviews_agg.columns if c != "combined_review"] + ["combined_review"]
reviews_agg = reviews_agg[cols]

# ----------------------------------------------
# Display sample rows
# ----------------------------------------------
reviews_agg.head()
# Out:
#                               movie_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  year  \
# 0  percy jackson & the olympians: the lightning t...  2010
# 1                                        please give  2010
# 2                                                 10  1979
# 3                    12 angry men (twelve angry men)  1957
# 4                       20,000 leagues under the sea  1954
#
#                                           movie_info  \
# 0  always trouble-prone, the life of teenager per...
# 1  kate (catherine keener) and her husband alex (...
# 2  a successful, middle-aged hollywood songwriter...
# 3  following the closing arguments in a murder tr...
# 4  in 1866, professor pierre m. aronnax (paul luk...
#
#                                               genres  \
# 0  action & adventure, comedy, drama, science fic...
# 1                                             comedy
# 2                                    comedy, romance
# 3                                    classics, drama
# 4           action & adventure, drama, kids & family
#
#                                      combined_review
# 0  whether audiences will get behind the lightnin...
# 1  holofcener always gives us more to chew on tha...
# 2  obvious but entertaining portrayal of midlife ...
# 3  in a time of bloated when special effects have...
# 4  [the] embodiment of disney at his best -- fami...

# %%
# Check how many times each movie_link appears
link_counts = reviews_agg['movie_link'].value_counts()
# Check how many times each movie_title appears
title_counts = reviews_agg['movie_title'].value_counts()

# Find links that appear more than once
duplicate_links = link_counts[link_counts > 1]
duplicate_titles= title_counts[title_counts > 1]

print(f"Number of movie_links appearing more than once: {len(duplicate_links)}")
print(f"Number of movie_titles appearing more than once: {len(duplicate_titles)}")
# Out:
# Number of movie_links appearing more than once: 0
# Number of movie_titles appearing more than once: 17

# %%
# Find all movie titles that appear more than once
duplicate_titles = reviews_agg["movie_title"].value_counts()
duplicate_titles = duplicate_titles[duplicate_titles > 1]

duplicate_titles
# Out:
# movie_title
# phantom of the opera                          2
# babes in toyland                              2
# all the king's men                            2
# the art of the steal                          2
# house on haunted hill                         2
# invaders from mars                            2
# don't be afraid of the dark                   2
# born to be wild                               2
# beauty and the beast (la belle et la bête)    2
# out of the dark                               2
# a star is born                                2
# a farewell to arms                            2
# murder on the orient express                  2
# our brand is crisis                           2
# rocketman                                     2
# the secret life of walter mitty               2
# take me to the river                          2
# Name: count, dtype: int64

# %%
# Show full duplicate entries with their reviews
duplicate_entries = reviews_agg[reviews_agg["movie_title"].isin(duplicate_titles.index)]

duplicate_entries
# Out:
#                                    movie_link  \
# 35                m/10004835-farewell_to_arms
# 60                m/1000654-all_the_kings_men
# 290                m/1001488-babes_in_toyland
# 296            m/1001902-beauty_and_the_beast
# 477           m/1010034-house_on_haunted_hill
# 492              m/1010672-invaders_from_mars
# 493              m/1010673-invaders_from_mars
# 604                 m/1015753-out_of_the_dark
# 611            m/1016240-phantom_of_the_opera
# 699                    m/1019828-star_is_born
# 700                    m/1019831-star_is_born
# 955                 m/1059867-born_to_be_wild
# 1148          m/1093881-house_on_haunted_hill
# 2285                      m/all_the_kings_men
# 2628                       m/art_of_the_steal
# 2977              m/beauty_and_the_beast_2014
# 3489                   m/born_to_be_wild_2011
# 5057             m/dont_be_afraid_of_the_dark
# 5058        m/dont_be_afraid_of_the_dark_2011
# 5654                       m/farewell_to_arms
# 9037           m/march_of_the_wooden_soldiers
# 9626           m/murder_on_the_orient_express
# 9627      m/murder_on_the_orient_express_2017
# 10267                   m/our_brand_is_crisis
# 10268              m/our_brand_is_crisis_2016
# 10291                  m/out_of_the_dark_2015
# 10544             m/phantom_of_the_opera_1943
# 11287                        m/rocketman_1997
# 11288                        m/rocketman_2019
# 11593           m/secret_life_of_walter_mitty
# 12692             m/take_me_to_the_river_2014
# 12693             m/take_me_to_the_river_2016
# 12983                  m/the_art_of_the_steal
# 14038  m/the_secret_life_of_walter_mitty_2013
#
#                                       movie_title  year  \
# 35                             a farewell to arms  1957
# 60                             all the king's men  1949
# 290                              babes in toyland  1961
# 296    beauty and the beast (la belle et la bête)  1946
# 477                         house on haunted hill  1959
# 492                            invaders from mars  1953
# 493                            invaders from mars  1986
# 604                               out of the dark  1989
# 611                          phantom of the opera  1925
# 699                                a star is born  1937
# 700                                a star is born  1976
# 955                               born to be wild  1995
# 1148                        house on haunted hill  1999
# 2285                           all the king's men  2006
# 2628                         the art of the steal  2010
# 2977   beauty and the beast (la belle et la bête)  2016
# 3489                              born to be wild  2011
# 5057                  don't be afraid of the dark  1973
# 5058                  don't be afraid of the dark  2011
# 5654                           a farewell to arms  1932
# 9037                             babes in toyland  1934
# 9626                 murder on the orient express  1974
# 9627                 murder on the orient express  2017
# 10267                         our brand is crisis  2005
# 10268                         our brand is crisis  2015
# 10291                             out of the dark  2015
# 10544                        phantom of the opera  1943
# 11287                                   rocketman  1997
# 11288                                   rocketman  2019
# 11593             the secret life of walter mitty  1947
# 12692                        take me to the river  2014
# 12693                        take me to the river  2016
# 12983                        the art of the steal  2014
# 14038             the secret life of walter mitty  2013
#
#                                               movie_info  \
# 35     based on the ernest hemingway novel, this worl...
# 60     drama about the rise and fall of a corrupt sou...
# 290    mary contrary (annette) is set to marry tom pi...
# 296    the story of a gentle-hearted beast in love wi...
# 477    rich oddball frederick loren (vincent price) h...
# 492    curious adolescent boy david maclean (jimmy hu...
# 493    a boy (hunter carson) sees his parents and nei...
# 604    an employee at a telephone fantasy service hel...
# 611    composer lord ambrose d'arcy (michael gough) a...
# 699    when a young actress (janet gaynor) arrives in...
# 700    a rock star on the decline, john norman howard...
# 955    a young female gorilla is captured in the moun...
# 1148   a millionaire with theatrical tendencies, step...
# 2285   charismatic southern politician willie stark's...
# 2628   this film looks at the controversy surrounding...
# 2977   a romance blossoms between the youngest daught...
# 3489   morgan freeman narrates this documentary about...
# 5057   a couple who inherited an old house learn they...
# 5058   lonely and introverted, young sally (bailee ma...
# 5654   frederic henry (gary cooper), an american driv...
# 9037   stannie dum (stan laurel) and ollie dee (olive...
# 9626   having concluded a case, detective hercule poi...
# 9627   a lavish trip through europe quickly unfolds i...
# 10267  bolivia is on the brink of a violent coup d'et...
# 10268  failing badly in the polls, a bolivian preside...
# 10291  a family moves to colombia to take over the op...
# 10544  talented christine (susanna foster) is unaware...
# 11287  a clumsy, impulsive scientist (harland william...
# 11288  young reginald dwight changes his name to elto...
# 11593  a mild-mannered pushover, walter mitty (danny ...
# 12692  music legends from stax records and memphis me...
# 12693  a gay teenager (logan miller) faces accusation...
# 12983  crunch calhoun (kurt russell), a motorcycle da...
# 14038  walter mitty (ben stiller), an employee at lif...
#
#                                                   genres  \
# 35                              classics, drama, romance
# 60                                       classics, drama
# 290    kids & family, musical & performing arts, roma...
# 296            drama, romance, science fiction & fantasy
# 477                              classics, drama, horror
# 492                  classics, science fiction & fantasy
# 493    horror, mystery & suspense, science fiction & ...
# 604            comedy, drama, horror, mystery & suspense
# 611                              classics, drama, horror
# 699                                      classics, drama
# 700            drama, musical & performing arts, romance
# 955     action & adventure, comedy, drama, kids & family
# 1148                          horror, mystery & suspense
# 2285                                               drama
# 2628              documentary, musical & performing arts
# 2977   mystery & suspense, romance, science fiction &...
# 3489                                         documentary
# 5057                                  horror, television
# 5058                          horror, mystery & suspense
# 5654                                      drama, romance
# 9037   comedy, musical & performing arts, science fic...
# 9626                                  mystery & suspense
# 9627                           drama, mystery & suspense
# 10267  art house & international, documentary, specia...
# 10268                                      comedy, drama
# 10291                         horror, mystery & suspense
# 10544  classics, drama, horror, musical & performing ...
# 11287           comedy, drama, science fiction & fantasy
# 11288                                              drama
# 11593                              comedy, kids & family
# 12692             documentary, musical & performing arts
# 12693                                              drama
# 12983                                             comedy
# 14038                  action & adventure, comedy, drama
#
#                                          combined_review
# 35     we have david o. selznick to blame for this bl...
# 60     rossen's film chronicles this life of raw powe...
# 290    a disgrace to the memory of laurel and hardy a...
# 296    one of the most magical of all films. jean coc...
# 477    giddy and fun... and scary if you're in the ri...
# 492    an enjoyable b-movie, but not quite as good as...
# 493    a clunky remake that fails to frighten fun and...
# 604    the identity of the murderer is a contrived su...
# 611    chaney is so effective, it is nearly impossibl...
# 699    william a. wellman's original 1937 a star is b...
# 700    it's streisand's movie, and streisand's charac...
# 955    obnoxious monkeyshines. most of the chances fo...
# 1148   ...too many special effects; not enough suspen...
# 2285   unlikely to win any best picture nominations, ...
# 2628   a fascinating, if overlong, look at a legacy p...
# 2977   beauty and the beast is sad, ridiculous and of...
# 3489   touching in a zoolike, rather than spectacular...
# 5057   if you were a child and saw it for the first t...
# 5058   'dark 'is an engaging, well-paced and scary ho...
# 5654   read the book it's not as good as the book, bu...
# 9037   fair is fair, so it really isn't a christmas m...
# 9626   to paraphrase comic book guy from the simpsons...
# 9627   this film never gets up a head of steam. where...
# 10267  an amazing insight into the corporate swill th...
# 10268  david gordon green's boisterous but hollow ele...
# 10291  derivative supernatural horror film. a solid g...
# 10544  if the film never goes full-tilt horror until ...
# 11287  rocketman is not inspired or brilliant or orig...
# 11288  taron is an incredible screen force with endle...
# 11593  great danny kaye fantasy-comedy, making far tu...
# 12692  you can't help but feel all the palpable joy i...
# 12693  "take me to the river" is ultimately about dar...
# 12983  the art of the steal is never beautiful, but i...
# 14038  the movie is lost in a walter mitty fantasy of...

# %%
# Create a combined text column for embeddings
reviews_agg['text_for_embedding'] = (
    reviews_agg['movie_title'].fillna('') + ' ' +
    reviews_agg['movie_info'].fillna('')+' '+
    reviews_agg['combined_review'].fillna('')
).str.strip()

# Keep relevant columns for embeddings including movie_title
embedding_df = reviews_agg[['movie_link', 'movie_title', 'year','genres', 'text_for_embedding']].copy()

# Check a few rows
print("Sample of combined text for embedding:")
display(embedding_df.head(5))
# Out:
# Sample of combined text for embedding:
#                               movie_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  year  \
# 0  percy jackson & the olympians: the lightning t...  2010
# 1                                        please give  2010
# 2                                                 10  1979
# 3                    12 angry men (twelve angry men)  1957
# 4                       20,000 leagues under the sea  1954
#
#                                               genres  \
# 0  action & adventure, comedy, drama, science fic...
# 1                                             comedy
# 2                                    comedy, romance
# 3                                    classics, drama
# 4           action & adventure, drama, kids & family
#
#                                   text_for_embedding
# 0  percy jackson & the olympians: the lightning t...
# 1  please give kate (catherine keener) and her hu...
# 2  10 a successful, middle-aged hollywood songwri...
# 3  12 angry men (twelve angry men) following the ...
# 4  20,000 leagues under the sea in 1866, professo...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from gensim.utils import simple_preprocess
import re

# -----------------------------------------
# 1. Setup stopwords
# -----------------------------------------
stop_words = set(stopwords.words('english'))
extra_stopwords = {"movie", "film", "films", "story", "character"}
stop_words.update(extra_stopwords)

# -----------------------------------------
# 2. Lemmatizer
# -----------------------------------------
lemmatizer = WordNetLemmatizer()

# -----------------------------------------
# 3. Cleaning 
# -----------------------------------------
def clean_text(text):
    # Keep letters only
    text = re.sub(r"[^a-zA-Z ]", " ", text)
    text = text.lower()
    return text

# -----------------------------------------
# 4. Tokenization + Lemmatization
# -----------------------------------------
def preprocess(text):
    tokens = simple_preprocess(text, deacc=True)

    # Remove stopwords + short words
    tokens = [t for t in tokens if t not in stop_words and len(t) > 2]

    # Lemmatize
    tokens = [lemmatizer.lemmatize(t) for t in tokens]

    return tokens

# -----------------------------------------
# 5. Apply to dataset
# -----------------------------------------
embedding_df["cleaned_text"] = embedding_df["text_for_embedding"].apply(clean_text)
embedding_df["tokens"] = embedding_df["cleaned_text"].apply(preprocess)

embedding_df[["movie_link", "movie_title","year", "genres", "tokens"]].head()
# Out:
#                               movie_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  year  \
# 0  percy jackson & the olympians: the lightning t...  2010
# 1                                        please give  2010
# 2                                                 10  1979
# 3                    12 angry men (twelve angry men)  1957
# 4                       20,000 leagues under the sea  1954
#
#                                               genres  \
# 0  action & adventure, comedy, drama, science fic...
# 1                                             comedy
# 2                                    comedy, romance
# 3                                    classics, drama
# 4           action & adventure, drama, kids & family
#
#                                               tokens
# 0  [percy, jackson, olympian, lightning, thief, a...
# 1  [please, give, kate, catherine, keener, husban...
# 2  [successful, middle, aged, hollywood, songwrit...
# 3  [angry, men, twelve, angry, men, following, cl...
# 4  [league, sea, professor, pierre, aronnax, paul...

# %%
from gensim.corpora import Dictionary

# Create dictionary from tokens
dictionary = Dictionary(embedding_df["tokens"])

# Filter very rare and very frequent words
dictionary.filter_extremes(no_below=15, no_above=0.5)

# Create bag-of-words corpus
corpus = [dictionary.doc2bow(tokens) for tokens in embedding_df["tokens"]]

print("Dictionary size:", len(dictionary))
print("Example BOW for first movie:", corpus[0][:10])
# Out:
# Dictionary size: 21998
# Example BOW for first movie: [(0, 1), (1, 1), (2, 1), (3, 1), (4, 8), (5, 3), (6, 1), (7, 1), (8, 7), (9, 1)]

# %%
#Topic weight distribution
from gensim.models.ldamodel import LdaModel

num_topics = 30

lda_model = LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=num_topics,
    random_state=42,
    passes=10,
    chunksize=2000,
    update_every=1,
    alpha='auto',
    eta='auto'
)

lda_model.print_topics(num_topics=10)
# Out:
# [(np.int64(12),
#   '0.065*"white" + 0.053*"ben" + 0.041*"cage" + 0.034*"russell" + 0.033*"abrams" + 0.027*"crowe" + 0.027*"stiller" + 0.023*"owen" + 0.020*"nicolas" + 0.019*"snow"'),
#  (np.int64(10),
#   '0.129*"jack" + 0.071*"mike" + 0.051*"howard" + 0.045*"vaughn" + 0.034*"sarah" + 0.031*"ted" + 0.031*"jon" + 0.026*"leigh" + 0.022*"nicholson" + 0.021*"baker"'),
#  (np.int64(25),
#   '0.029*"man" + 0.019*"comic" + 0.017*"spider" + 0.017*"superhero" + 0.015*"book" + 0.013*"marvel" + 0.011*"anderson" + 0.011*"fun" + 0.008*"best" + 0.008*"men"'),
#  (np.int64(26),
#   '0.075*"paul" + 0.033*"lewis" + 0.032*"hitchcock" + 0.027*"wood" + 0.026*"tower" + 0.024*"theron" + 0.016*"joan" + 0.015*"lynch" + 0.013*"marsh" + 0.013*"sleep"'),
#  (np.int64(11),
#   '0.048*"adam" + 0.041*"sandler" + 0.032*"wild" + 0.027*"animal" + 0.021*"food" + 0.020*"murphy" + 0.018*"eddie" + 0.015*"ice" + 0.014*"herzog" + 0.013*"payne"'),
#  (np.int64(27),
#   '0.013*"life" + 0.011*"family" + 0.008*"heart" + 0.008*"young" + 0.007*"age" + 0.006*"world" + 0.006*"way" + 0.006*"feel" + 0.006*"child" + 0.005*"coming"'),
#  (np.int64(21),
#   '0.022*"performance" + 0.015*"drama" + 0.007*"well" + 0.007*"life" + 0.006*"actor" + 0.005*"feel" + 0.005*"director" + 0.004*"emotional" + 0.004*"best" + 0.004*"true"'),
#  (np.int64(2),
#   '0.008*"bad" + 0.005*"would" + 0.005*"get" + 0.005*"enough" + 0.004*"little" + 0.004*"audience" + 0.004*"plot" + 0.004*"thing" + 0.004*"nothing" + 0.004*"better"'),
#  (np.int64(6),
#   '0.007*"director" + 0.006*"work" + 0.004*"way" + 0.004*"best" + 0.004*"year" + 0.004*"cinema" + 0.004*"performance" + 0.004*"experience" + 0.003*"art" + 0.003*"may"'),
#  (np.int64(13),
#   '0.010*"comedy" + 0.007*"character" + 0.006*"performance" + 0.005*"cast" + 0.005*"little" + 0.005*"romantic" + 0.005*"life" + 0.004*"actor" + 0.004*"director" + 0.004*"get"')]

# %%
# Check genre column
embedding_df["genres"] = embedding_df["genres"].fillna("").astype(str)

embedding_df["genre_list"] = embedding_df["genres"].apply(
    lambda x: [g.strip() for g in x.split(",")] if x.strip() else []
)

print("Sample genres (raw):")
display(embedding_df["genres"].iloc[:5])
print("Sample genre_list (raw):")
display(embedding_df["genre_list"].iloc[:5])
# Out:
# Sample genres (raw):
# 0    action & adventure, comedy, drama, science fic...
# 1                                               comedy
# 2                                      comedy, romance
# 3                                      classics, drama
# 4             action & adventure, drama, kids & family
# Name: genres, dtype: object
# Sample genre_list (raw):
# 0    [action & adventure, comedy, drama, science fi...
# 1                                             [comedy]
# 2                                    [comedy, romance]
# 3                                    [classics, drama]
# 4           [action & adventure, drama, kids & family]
# Name: genre_list, dtype: object

# %%
# list unique raw tokens and counts for inspection
from collections import Counter
flat = [g.strip() for lst in embedding_df['genre_list'] for g in lst if isinstance(g, str) and g.strip()]
genre_counts = Counter(flat)
import pandas as pd
genre_df = pd.DataFrame.from_records(list(genre_counts.items()), columns=['genre_raw','count']).sort_values('count', ascending=False).reset_index(drop=True)
print("Unique raw genres:", len(genre_df))
display(genre_df.head(80))
# Out:
# Unique raw genres: 21
#                     genre_raw  count
# 0                       drama   8671
# 1                      comedy   5161
# 2          action & adventure   3174
# 3          mystery & suspense   3151
# 4   art house & international   2267
# 5                 documentary   1789
# 6                     romance   1764
# 7                      horror   1730
# 8   science fiction & fantasy   1681
# 9                    classics   1547
# 10           special interest   1138
# 11              kids & family    995
# 12  musical & performing arts    909
# 13                  animation    529
# 14                    western    282
# 15                 television    201
# 16           sports & fitness    162
# 17                cult movies     97
# 18       faith & spirituality     71
# 19              gay & lesbian     69
# 20              anime & manga     18

# %%
# -----------------------------------------
# Genre Normalization Map
# -----------------------------------------
genre_map = {
    "art house & international": "international",
    "special interest": "documentary",
    "faith & spirituality": "drama",
    "gay & lesbian": "romance",
    "anime & manga": "animation and manga",
    "animation": "animation and manga",
}

# Genres to completely drop
drop_genres = {"cult movies"}

# -----------------------------------------
# Apply the mapping
# -----------------------------------------
def normalize_genre_list(genre_list):
    cleaned = []

    for g in genre_list:
        g = g.strip().lower()

        # Drop unwanted genres
        if g in drop_genres:
            continue

        # Replace using the mapping
        if g in genre_map:
            cleaned.append(genre_map[g])
        else:
            cleaned.append(g)

    return cleaned

# Apply to dataframe
embedding_df["genre_list"] = embedding_df["genre_list"].apply(normalize_genre_list)

# check new distribution
from collections import Counter
flat = [g for lst in embedding_df["genre_list"] for g in lst]
Counter(flat)
# Out:
# Counter({'drama': 8742,
#          'comedy': 5161,
#          'action & adventure': 3174,
#          'mystery & suspense': 3151,
#          'documentary': 2927,
#          'international': 2267,
#          'romance': 1833,
#          'horror': 1730,
#          'science fiction & fantasy': 1681,
#          'classics': 1547,
#          'kids & family': 995,
#          'musical & performing arts': 909,
#          'animation and manga': 547,
#          'western': 282,
#          'television': 201,
#          'sports & fitness': 162})

# %%
# -----------------------------------------
# 1. Compute per-document topic distributions
# -----------------------------------------
import numpy as np
import pandas as pd

# Function to get dense topic vector from LDA for a single document
def get_topic_vector(bow, num_topics=num_topics):
    topic_dist = lda_model.get_document_topics(bow, minimum_probability=0)
    # Convert to dense vector
    vec = np.zeros(num_topics)
    for topic_id, prob in topic_dist:
        vec[topic_id] = prob
    return vec

# Apply to all documents in embedding_df
topic_vectors = [get_topic_vector(bow) for bow in corpus]  # corpus is your BoW corpus

# Convert to DataFrame and assign topic columns
topic_cols = [f"Topic_{i}" for i in range(num_topics)]
topic_df = pd.DataFrame(topic_vectors, columns=topic_cols)

# Merge topic columns into embedding_df
embedding_df = pd.concat([embedding_df.reset_index(drop=True), topic_df], axis=1)

# inspect
embedding_df.head()
# Out:
#                               movie_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  year  \
# 0  percy jackson & the olympians: the lightning t...  2010
# 1                                        please give  2010
# 2                                                 10  1979
# 3                    12 angry men (twelve angry men)  1957
# 4                       20,000 leagues under the sea  1954
#
#                                               genres  \
# 0  action & adventure, comedy, drama, science fic...
# 1                                             comedy
# 2                                    comedy, romance
# 3                                    classics, drama
# 4           action & adventure, drama, kids & family
#
#                                   text_for_embedding  \
# 0  percy jackson & the olympians: the lightning t...
# 1  please give kate (catherine keener) and her hu...
# 2  10 a successful, middle-aged hollywood songwri...
# 3  12 angry men (twelve angry men) following the ...
# 4  20,000 leagues under the sea in 1866, professo...
#
#                                         cleaned_text  \
# 0  percy jackson   the olympians  the lightning t...
# 1  please give kate  catherine keener  and her hu...
# 2     a successful  middle aged hollywood songwri...
# 3     angry men  twelve angry men  following the ...
# 4         leagues under the sea in       professo...
#
#                                               tokens  \
# 0  [percy, jackson, olympian, lightning, thief, a...
# 1  [please, give, kate, catherine, keener, husban...
# 2  [successful, middle, aged, hollywood, songwrit...
# 3  [angry, men, twelve, angry, men, following, cl...
# 4  [league, sea, professor, pierre, aronnax, paul...
#
#                                           genre_list   Topic_0   Topic_1  ...  \
# 0  [action & adventure, comedy, drama, science fi...  0.270608  0.094149  ...
# 1                                           [comedy]  0.009428  0.008242  ...
# 2                                  [comedy, romance]  0.000412  0.000849  ...
# 3                                  [classics, drama]  0.000138  0.000284  ...
# 4         [action & adventure, drama, kids & family]  0.000322  0.080926  ...
#
#    Topic_20  Topic_21  Topic_22  Topic_23  Topic_24  Topic_25  Topic_26  \
# 0  0.000037  0.006122  0.062962  0.000095  0.138425  0.008029  0.000027
# 1  0.000043  0.048975  0.000065  0.078424  0.000038  0.000030  0.000031
# 2  0.000401  0.071800  0.000603  0.131915  0.000355  0.000282  0.000290
# 3  0.000134  0.150026  0.000202  0.000344  0.000119  0.034493  0.000097
# 4  0.000313  0.048983  0.366879  0.000801  0.269460  0.092399  0.033010
#
#    Topic_27  Topic_28  Topic_29
# 0  0.033446  0.015039  0.000094
# 1  0.176481  0.000041  0.040789
# 2  0.001378  0.000384  0.283029
# 3  0.056764  0.000129  0.000340
# 4  0.001072  0.000299  0.000793
#
# [5 rows x 38 columns]

# %%
# -----------------------------------------
# 2. Expand genres into rows (one genre per row per movie)
# -----------------------------------------
movies_exploded = (
    embedding_df
    .assign(genre_list=embedding_df["genre_list"])  # make sure we use cleaned genre_list
    .explode("genre_list")
)

# Remove empty/None genres just in case
movies_exploded = movies_exploded[movies_exploded["genre_list"].notna()]
movies_exploded["genre_list"] = movies_exploded["genre_list"].str.strip()

# -----------------------------------------
# 3. Identify topic columns
# -----------------------------------------
topic_cols = [col for col in movies_exploded.columns if col.startswith("Topic_")]

# -----------------------------------------
# 4. Compute average topic weight per genre
# -----------------------------------------
genre_topic_weights = (
    movies_exploded
    .groupby("genre_list")[topic_cols]
    .mean()
)

# inspect results
genre_topic_weights.head()
# Out:
#                       Topic_0   Topic_1   Topic_2   Topic_3   Topic_4  \
# genre_list
# action & adventure   0.050188  0.036705  0.108424  0.027803  0.021457
# animation and manga  0.030432  0.035133  0.104640  0.034401  0.012225
# classics             0.012633  0.029063  0.033096  0.056796  0.030033
# comedy               0.010771  0.025716  0.111752  0.039137  0.016539
# documentary          0.007105  0.015362  0.046214  0.016806  0.010532
#
#                       Topic_5   Topic_6   Topic_7   Topic_8   Topic_9  ...  \
# genre_list                                                             ...
# action & adventure   0.052747  0.051838  0.015446  0.081323  0.046851  ...
# animation and manga  0.005823  0.066203  0.015307  0.009105  0.014438  ...
# classics             0.038278  0.074327  0.037880  0.028670  0.019839  ...
# comedy               0.017901  0.050217  0.021335  0.019049  0.011458  ...
# documentary          0.009619  0.105944  0.260892  0.012129  0.007500  ...
#
#                      Topic_20  Topic_21  Topic_22  Topic_23  Topic_24  \
# genre_list
# action & adventure   0.016422  0.052154  0.056882  0.014604  0.036513
# animation and manga  0.003665  0.016186  0.042185  0.010461  0.273468
# classics             0.033152  0.064099  0.031356  0.063208  0.014697
# comedy               0.009211  0.044864  0.015403  0.043815  0.028767
# documentary          0.004729  0.048401  0.021501  0.020556  0.009008
#
#                      Topic_25  Topic_26  Topic_27  Topic_28  Topic_29
# genre_list
# action & adventure   0.018566  0.003875  0.032900  0.007619  0.042154
# animation and manga  0.015209  0.003714  0.094191  0.005840  0.040521
# classics             0.004689  0.010190  0.030484  0.010294  0.029707
# comedy               0.006305  0.003984  0.063108  0.007525  0.146604
# documentary          0.004400  0.003326  0.084438  0.008684  0.022373
#
# [5 rows x 30 columns]

# %%
import pandas as pd
import numpy as np

# -----------------------------------------
# Prepare topic matrices
# -----------------------------------------
# movie_topic_matrix: rows = movies, columns = topics
movie_topic_matrix = embedding_df[[col for col in embedding_df.columns if col.startswith("Topic_")]].values

# genre_topic_matrix: rows = genres, columns = topics
genre_topic_matrix = genre_topic_weights.values
genre_list = genre_topic_weights.index.tolist()

# -----------------------------------------
# Compute weighted genre scores per movie
# -----------------------------------------
weighted_scores = movie_topic_matrix @ genre_topic_matrix.T  # matrix multiplication
weighted_scores_df = pd.DataFrame(weighted_scores, columns=genre_list, index=embedding_df.index)

# -----------------------------------------
# Select top 5 genres per movie
# -----------------------------------------
top_n = 5
def top_n_genres(row, n=top_n):
    top_scores = row.nlargest(n)
    # Normalize to 100%
    top_scores_normalized = (100 * top_scores / top_scores.sum()).round(0).astype(int)
    return pd.Series(top_scores_normalized)

top_genres_df = weighted_scores_df.apply(top_n_genres, axis=1)

# -----------------------------------------
# Combine with movie info
# -----------------------------------------
movie_genres_df = pd.concat([embedding_df[["movie_link","movie_title","year"]], top_genres_df], axis=1)
movie_genres_df.head()
# Out:
#                               movie_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  year  \
# 0  percy jackson & the olympians: the lightning t...  2010
# 1                                        please give  2010
# 2                                                 10  1979
# 3                    12 angry men (twelve angry men)  1957
# 4                       20,000 leagues under the sea  1954
#
#    action & adventure  animation and manga  classics  comedy  documentary  \
# 0                17.0                 26.0       NaN    13.0          NaN
# 1                 NaN                  NaN      16.0    24.0          NaN
# 2                 NaN                  NaN       NaN    27.0          NaN
# 3                 NaN                  NaN      18.0     NaN         20.0
# 4                14.0                 31.0       NaN     NaN          NaN
#
#    drama  horror  international  kids & family  musical & performing arts  \
# 0    NaN     NaN            NaN           24.0                        NaN
# 1   19.0     NaN           18.0            NaN                        NaN
# 2    NaN     NaN            NaN            NaN                       18.0
# 3   21.0     NaN           23.0            NaN                        NaN
# 4    NaN    11.0            NaN           23.0                        NaN
#
#    mystery & suspense  romance  science fiction & fantasy  sports & fitness  \
# 0                 NaN      NaN                       19.0               NaN
# 1                 NaN     24.0                        NaN               NaN
# 2                 NaN     22.0                        NaN              16.0
# 3                18.0      NaN                        NaN               NaN
# 4                 NaN      NaN                       22.0               NaN
#
#    television  western
# 0         NaN      NaN
# 1         NaN      NaN
# 2        17.0      NaN
# 3         NaN      NaN
# 4         NaN      NaN

# %%
from fuzzywuzzy import process
import matplotlib.pyplot as plt

# Build lowercase title → row mapping
title_map = {row["movie_title"].strip().lower(): row for idx, row in movie_genres_df.iterrows()}
all_titles = movie_genres_df["movie_title"].tolist()
lower_titles = [t.lower() for t in all_titles]
all_years = movie_genres_df["year"].tolist()

# Function to show genre plot sorted descending (highest at top)
def show_genre_plot(movie_title):
    row = title_map[movie_title.lower()]
    genre_cols = [c for c in movie_genres_df.columns if c not in ["movie_link","movie_title","year"]]
    genres = row[genre_cols].dropna()
    
    # Sort genres descending
    genres = genres.sort_values(ascending=False)
    
    plt.figure(figsize=(8,5))
    # Reverse order for barh to put highest at top
    ax = genres[::-1].plot(kind='barh')
    plt.title(f"Genre Percentages for '{row['movie_title']}' ({row['year']})")
    plt.xlabel("Percentage")
    
    # Add percentage labels inside the bars
    for bar in ax.patches:
        ax.text(
            bar.get_width() / 2,                      # x position
            bar.get_y() + bar.get_height() / 2,       # y position
            f"{int(bar.get_width())}%",                # label text
            ha='center',
            va='center'
        )
    plt.tight_layout()
    plt.savefig(f"Genre Percentages for '{row['movie_title']}' ({row['year']}).jpg")
    plt.show()
    
    print("\n🎬 Genre Percentages (highest → lowest):")
    print(genres)

# Single search cycle
user_text = input("🎬 Enter movie name: ").strip()
user_text_lower = user_text.lower()

# Exact match
if user_text_lower in title_map:
    print(f"🎯 Exact match found: {title_map[user_text_lower]['movie_title']} ({title_map[user_text_lower]['year']})\n")
    show_genre_plot(title_map[user_text_lower]['movie_title'])
else:
    # Fuzzy suggestions
    suggestions = process.extract(user_text_lower, lower_titles, limit=5)
    print("❌ Exact match not found.\n🔎 Did you mean one of these?\n")
    
    for i, (suggestion_text, score) in enumerate(suggestions, start=1):
        idx = lower_titles.index(suggestion_text)
        real_title = all_titles[idx]
        year = all_years[idx]
        print(f"{i}. {real_title} ({year})  ({score}%)")
    
    # Ask user to select suggestion by number
    selection = input("\nType the number of the movie you want to select (or 0 to cancel): ").strip()
    if selection.isdigit():
        selection = int(selection)
        if 1 <= selection <= len(suggestions):
            idx = lower_titles.index(suggestions[selection-1][0])
            selected_title = all_titles[idx]
            print(f"\n🎯 You selected: {selected_title}\n")
            show_genre_plot(selected_title)
        else:
            print("❌ Selection cancelled.")
    else:
        print("❌ Invalid input. Selection cancelled.")
# Out:
# 🎬 Enter movie name:  Harry Potter
# ❌ Exact match not found.
# 🔎 Did you mean one of these?
#
# 1. harry potter and the chamber of secrets (2002)  (90%)
# 2. harry potter and the deathly hallows - part 1 (2010)  (90%)
# 3. harry potter and the deathly hallows - part 2 (2011)  (90%)
# 4. harry potter and the goblet of fire (2005)  (90%)
# 5. harry potter and the half-blood prince (2009)  (90%)
# Type the number of the movie you want to select (or 0 to cancel):  1
# 🎯 You selected: harry potter and the chamber of secrets
# 🎬 Genre Percentages (highest → lowest):
# animation and manga          27.0
# kids & family                22.0
# science fiction & fantasy    19.0
# action & adventure           17.0
# horror                       15.0
# Name: 6765, dtype: object

# %%
# -------------------------------
# Full pipeline: Best dictionary + best topics
# -------------------------------

from gensim.corpora import Dictionary
from gensim.models import LdaModel, CoherenceModel
import pandas as pd
import itertools
import matplotlib.pyplot as plt

# -------------------------------
# User parameters
# -------------------------------
texts = embedding_df["tokens"].tolist()
no_below_values = [12, 10, 7, 5]     # candidate no_below
no_above_values = [0.5, 0.6, 0.7]   # candidate no_above
topic_numbers = [8, 10, 12, 15]      # candidate topics for coherence
passes = 5                             # smaller passes for speed (coherence sweep)

results = []

# -------------------------------
# Run grid search
# -------------------------------
for nb, na in itertools.product(no_below_values, no_above_values):
    # 1️⃣ Build dictionary
    dictionary = Dictionary(texts)
    dictionary.filter_extremes(no_below=nb, no_above=na)
    
    # 2️⃣ Build corpus
    corpus = [dictionary.doc2bow(doc) for doc in texts]
    
    # Skip if dictionary is too small
    if len(dictionary) < 50:
        continue
    
    # 3️⃣ Try different number of topics
    for num_topics in topic_numbers:
        lda_model = LdaModel(
            corpus=corpus,
            id2word=dictionary,
            num_topics=num_topics,
            passes=passes,
            random_state=42,
            alpha='auto',
            eta='auto'
        )
        
        # 4️⃣ Compute coherence
        coherencemodel = CoherenceModel(
            model=lda_model,
            texts=texts,
            dictionary=dictionary,
            coherence='c_v'
        )
        coherence = coherencemodel.get_coherence()
        
        # Store results
        results.append({
            "no_below": nb,
            "no_above": na,
            "num_topics": num_topics,
            "dictionary_size": len(dictionary),
            "coherence": coherence
        })
        
        print(f"✅ no_below={nb}, no_above={na}, topics={num_topics}, dict_size={len(dictionary)}, coherence={coherence:.4f}")

# -------------------------------
# Results DataFrame
# -------------------------------
results_df = pd.DataFrame(results)
results_df = results_df.sort_values("coherence", ascending=False).reset_index(drop=True)
display(results_df.head(10))  # show top 10 combinations

# -------------------------------
# Best combination
# -------------------------------
best = results_df.iloc[0]
print("\n🏆 Best dictionary + topic combination:")
print(f"no_below={best['no_below']}, no_above={best['no_above']}, num_topics={best['num_topics']}, dict_size={best['dictionary_size']}, coherence={best['coherence']:.4f}")

# -------------------------------
# Plot coherence heatmap
# -------------------------------
import seaborn as sns

plt.figure(figsize=(10,6))
sns.heatmap(
    results_df.pivot_table(index='no_below', columns='no_above', values='coherence', aggfunc='max'),
    annot=True, fmt=".3f",
    cmap="YlGnBu"
)
plt.title("Max coherence for different (no_below, no_above, num_topics)")
plt.savefig("Max coherence for different (no_below, no_above, num_topics).jpg")
plt.show()
# Out:
# ✅ no_below=12, no_above=0.5, topics=8, dict_size=24473, coherence=0.3488
# ✅ no_below=12, no_above=0.5, topics=10, dict_size=24473, coherence=0.3406
# ✅ no_below=12, no_above=0.5, topics=12, dict_size=24473, coherence=0.3636
# ✅ no_below=12, no_above=0.5, topics=15, dict_size=24473, coherence=0.3732
# ✅ no_below=12, no_above=0.6, topics=8, dict_size=24478, coherence=0.3240
# ✅ no_below=12, no_above=0.6, topics=10, dict_size=24478, coherence=0.3286
# ✅ no_below=12, no_above=0.6, topics=12, dict_size=24478, coherence=0.3147
# ✅ no_below=12, no_above=0.6, topics=15, dict_size=24478, coherence=0.3333
# ✅ no_below=12, no_above=0.7, topics=8, dict_size=24479, coherence=0.3333
# ✅ no_below=12, no_above=0.7, topics=10, dict_size=24479, coherence=0.3326
# ✅ no_below=12, no_above=0.7, topics=12, dict_size=24479, coherence=0.3262
# ✅ no_below=12, no_above=0.7, topics=15, dict_size=24479, coherence=0.3427
# ✅ no_below=10, no_above=0.5, topics=8, dict_size=26665, coherence=0.3396
# ✅ no_below=10, no_above=0.5, topics=10, dict_size=26665, coherence=0.3515
# ✅ no_below=10, no_above=0.5, topics=12, dict_size=26665, coherence=0.3510
# ✅ no_below=10, no_above=0.5, topics=15, dict_size=26665, coherence=0.3528
# ✅ no_below=10, no_above=0.6, topics=8, dict_size=26670, coherence=0.3166
# ✅ no_below=10, no_above=0.6, topics=10, dict_size=26670, coherence=0.3372
# ✅ no_below=10, no_above=0.6, topics=12, dict_size=26670, coherence=0.3437
# ✅ no_below=10, no_above=0.6, topics=15, dict_size=26670, coherence=0.3448
# ✅ no_below=10, no_above=0.7, topics=8, dict_size=26671, coherence=0.3258
# ✅ no_below=10, no_above=0.7, topics=10, dict_size=26671, coherence=0.3289
# ✅ no_below=10, no_above=0.7, topics=12, dict_size=26671, coherence=0.3216
# ✅ no_below=10, no_above=0.7, topics=15, dict_size=26671, coherence=0.3325
# ✅ no_below=7, no_above=0.5, topics=8, dict_size=31414, coherence=0.3438
# ✅ no_below=7, no_above=0.5, topics=10, dict_size=31414, coherence=0.3597
# ✅ no_below=7, no_above=0.5, topics=12, dict_size=31414, coherence=0.3703
# ✅ no_below=7, no_above=0.5, topics=15, dict_size=31414, coherence=0.3572
# ✅ no_below=7, no_above=0.6, topics=8, dict_size=31419, coherence=0.3142
# ✅ no_below=7, no_above=0.6, topics=10, dict_size=31419, coherence=0.3382
# ✅ no_below=7, no_above=0.6, topics=12, dict_size=31419, coherence=0.3464
# ✅ no_below=7, no_above=0.6, topics=15, dict_size=31419, coherence=0.3490
# ✅ no_below=7, no_above=0.7, topics=8, dict_size=31420, coherence=0.3252
# ✅ no_below=7, no_above=0.7, topics=10, dict_size=31420, coherence=0.3197
# ✅ no_below=7, no_above=0.7, topics=12, dict_size=31420, coherence=0.3371
# ✅ no_below=7, no_above=0.7, topics=15, dict_size=31420, coherence=0.3317
# ✅ no_below=5, no_above=0.5, topics=8, dict_size=36615, coherence=0.3468
# ✅ no_below=5, no_above=0.5, topics=10, dict_size=36615, coherence=0.3596
# ✅ no_below=5, no_above=0.5, topics=12, dict_size=36615, coherence=0.3731
# ✅ no_below=5, no_above=0.5, topics=15, dict_size=36615, coherence=0.3665
# ✅ no_below=5, no_above=0.6, topics=8, dict_size=36620, coherence=0.3199
# ✅ no_below=5, no_above=0.6, topics=10, dict_size=36620, coherence=0.3294
# ✅ no_below=5, no_above=0.6, topics=12, dict_size=36620, coherence=0.3398
# ✅ no_below=5, no_above=0.6, topics=15, dict_size=36620, coherence=0.3411
# ✅ no_below=5, no_above=0.7, topics=8, dict_size=36621, coherence=0.3200
# ✅ no_below=5, no_above=0.7, topics=10, dict_size=36621, coherence=0.3498
# ✅ no_below=5, no_above=0.7, topics=12, dict_size=36621, coherence=0.3574
# ✅ no_below=5, no_above=0.7, topics=15, dict_size=36621, coherence=0.3423
#    no_below  no_above  num_topics  dictionary_size  coherence
# 0        12       0.5          15            24473   0.373194
# 1         5       0.5          12            36615   0.373140
# 2         7       0.5          12            31414   0.370332
# 3         5       0.5          15            36615   0.366474
# 4        12       0.5          12            24473   0.363585
# 5         7       0.5          10            31414   0.359682
# 6         5       0.5          10            36615   0.359609
# 7         5       0.7          12            36621   0.357413
# 8         7       0.5          15            31414   0.357158
# 9        10       0.5          15            26665   0.352817
# 🏆 Best dictionary + topic combination:
# no_below=12.0, no_above=0.5, num_topics=15.0, dict_size=24473.0, coherence=0.3732

# %%
# -------------------------------
# Full pipeline: Best dictionary + best topics
# -------------------------------

from gensim.corpora import Dictionary
from gensim.models import LdaModel, CoherenceModel
import pandas as pd
import itertools
import matplotlib.pyplot as plt

# -------------------------------
# User parameters
# -------------------------------
texts = embedding_df["tokens"].tolist()
no_below_values = [12, 15, 18, 20]     # candidate no_below
no_above_values = [0.5]   # candidate no_above
topic_numbers = [15, 20, 25, 30]      # candidate topics for coherence
passes = 5                             # smaller passes for speed (coherence sweep)

results = []

# -------------------------------
# Run grid search
# -------------------------------
for nb, na in itertools.product(no_below_values, no_above_values):
    # 1️⃣ Build dictionary
    dictionary = Dictionary(texts)
    dictionary.filter_extremes(no_below=nb, no_above=na)
    
    # 2️⃣ Build corpus
    corpus = [dictionary.doc2bow(doc) for doc in texts]
    
    # Skip if dictionary is too small
    if len(dictionary) < 50:
        continue
    
    # 3️⃣ Try different number of topics
    for num_topics in topic_numbers:
        lda_model = LdaModel(
            corpus=corpus,
            id2word=dictionary,
            num_topics=num_topics,
            passes=passes,
            random_state=42,
            alpha='auto',
            eta='auto'
        )
        
        # 4️⃣ Compute coherence
        coherencemodel = CoherenceModel(
            model=lda_model,
            texts=texts,
            dictionary=dictionary,
            coherence='c_v'
        )
        coherence = coherencemodel.get_coherence()
        
        # Store results
        results.append({
            "no_below": nb,
            "no_above": na,
            "num_topics": num_topics,
            "dictionary_size": len(dictionary),
            "coherence": coherence
        })
        
        print(f"✅ no_below={nb}, no_above={na}, topics={num_topics}, dict_size={len(dictionary)}, coherence={coherence:.4f}")

# -------------------------------
# Results DataFrame
# -------------------------------
results_df = pd.DataFrame(results)
results_df = results_df.sort_values("coherence", ascending=False).reset_index(drop=True)
display(results_df.head(10))  # show top 10 combinations

# -------------------------------
# Best combination
# -------------------------------
best = results_df.iloc[0]
print("\n🏆 Best dictionary + topic combination:")
print(f"no_below={best['no_below']}, no_above={best['no_above']}, num_topics={best['num_topics']}, dict_size={best['dictionary_size']}, coherence={best['coherence']:.4f}")

# -------------------------------
# Plot coherence heatmap
# -------------------------------
import seaborn as sns

plt.figure(figsize=(10,6))
sns.heatmap(
    results_df.pivot_table(index='no_below', columns='num_topics', values='coherence', aggfunc='max'),
    annot=True, fmt=".3f",
    cmap="YlGnBu"
)
plt.title("Max coherence for different (no_below, num_topics)")
plt.savefig("Max coherence for different (no_below, num_topics).jpg")
plt.show()
# Out:
# ✅ no_below=12, no_above=0.5, topics=15, dict_size=24473, coherence=0.3732
# ✅ no_below=12, no_above=0.5, topics=20, dict_size=24473, coherence=0.3639
# ✅ no_below=12, no_above=0.5, topics=25, dict_size=24473, coherence=0.3808
# ✅ no_below=12, no_above=0.5, topics=30, dict_size=24473, coherence=0.3717
# ✅ no_below=15, no_above=0.5, topics=15, dict_size=21998, coherence=0.3617
# ✅ no_below=15, no_above=0.5, topics=20, dict_size=21998, coherence=0.3758
# ✅ no_below=15, no_above=0.5, topics=25, dict_size=21998, coherence=0.3831
# ✅ no_below=15, no_above=0.5, topics=30, dict_size=21998, coherence=0.3878
# ✅ no_below=18, no_above=0.5, topics=15, dict_size=20131, coherence=0.3609
# ✅ no_below=18, no_above=0.5, topics=20, dict_size=20131, coherence=0.3662
# ✅ no_below=18, no_above=0.5, topics=25, dict_size=20131, coherence=0.3853
# ✅ no_below=18, no_above=0.5, topics=30, dict_size=20131, coherence=0.3813
# ✅ no_below=20, no_above=0.5, topics=15, dict_size=19058, coherence=0.3807
# ✅ no_below=20, no_above=0.5, topics=20, dict_size=19058, coherence=0.3723
# ✅ no_below=20, no_above=0.5, topics=25, dict_size=19058, coherence=0.3802
# ✅ no_below=20, no_above=0.5, topics=30, dict_size=19058, coherence=0.3878
#    no_below  no_above  num_topics  dictionary_size  coherence
# 0        15       0.5          30            21998   0.387806
# 1        20       0.5          30            19058   0.387769
# 2        18       0.5          25            20131   0.385339
# 3        15       0.5          25            21998   0.383086
# 4        18       0.5          30            20131   0.381329
# 5        12       0.5          25            24473   0.380757
# 6        20       0.5          15            19058   0.380653
# 7        20       0.5          25            19058   0.380201
# 8        15       0.5          20            21998   0.375768
# 9        12       0.5          15            24473   0.373194
# 🏆 Best dictionary + topic combination:
# no_below=15.0, no_above=0.5, num_topics=30.0, dict_size=21998.0, coherence=0.3878

# %%
# -------------------------------
# Full pipeline: Best dictionary + best topics
# -------------------------------

from gensim.corpora import Dictionary
from gensim.models import LdaModel, CoherenceModel
import pandas as pd
import itertools
import matplotlib.pyplot as plt

# -------------------------------
# User parameters
# -------------------------------
texts = embedding_df["tokens"].tolist()
no_below_values = [15]     # candidate no_below
no_above_values = [0.5]   # candidate no_above
topic_numbers = [30,35,40,45]      # candidate topics for coherence
passes = 5                             # smaller passes for speed (coherence sweep)

results = []

# -------------------------------
# Run grid search
# -------------------------------
for nb, na in itertools.product(no_below_values, no_above_values):
    # 1️⃣ Build dictionary
    dictionary = Dictionary(texts)
    dictionary.filter_extremes(no_below=nb, no_above=na)
    
    # 2️⃣ Build corpus
    corpus = [dictionary.doc2bow(doc) for doc in texts]
    
    # Skip if dictionary is too small
    if len(dictionary) < 50:
        continue
    
    # 3️⃣ Try different number of topics
    for num_topics in topic_numbers:
        lda_model = LdaModel(
            corpus=corpus,
            id2word=dictionary,
            num_topics=num_topics,
            passes=passes,
            random_state=42,
            alpha='auto',
            eta='auto'
        )
        
        # 4️⃣ Compute coherence
        coherencemodel = CoherenceModel(
            model=lda_model,
            texts=texts,
            dictionary=dictionary,
            coherence='c_v'
        )
        coherence = coherencemodel.get_coherence()
        
        # Store results
        results.append({
            "no_below": nb,
            "no_above": na,
            "num_topics": num_topics,
            "dictionary_size": len(dictionary),
            "coherence": coherence
        })
        
        print(f"✅ no_below={nb}, no_above={na}, topics={num_topics}, dict_size={len(dictionary)}, coherence={coherence:.4f}")

# -------------------------------
# Results DataFrame
# -------------------------------
results_df = pd.DataFrame(results)
results_df = results_df.sort_values("coherence", ascending=False).reset_index(drop=True)
display(results_df.head(10))  # show top 10 combinations

# -------------------------------
# Best combination
# -------------------------------
best = results_df.iloc[0]
print("\n🏆 Best dictionary + topic combination:")
print(f"no_below={best['no_below']}, no_above={best['no_above']}, num_topics={best['num_topics']}, dict_size={best['dictionary_size']}, coherence={best['coherence']:.4f}")

# -------------------------------
# Plot coherence heatmap
# -------------------------------
import seaborn as sns

plt.figure(figsize=(10,6))
sns.heatmap(
    results_df.pivot_table(index='num_topics', columns='no_below', values='coherence', aggfunc='max'),
    annot=True, fmt=".3f",
    cmap="YlGnBu"
)
plt.title("Max coherence for different (num_topics)")
plt.savefig("Max coherence for different (num_topics).jpg")
plt.show()
# Out:
# ✅ no_below=15, no_above=0.5, topics=30, dict_size=21998, coherence=0.3878
# ✅ no_below=15, no_above=0.5, topics=35, dict_size=21998, coherence=0.3782
# ✅ no_below=15, no_above=0.5, topics=40, dict_size=21998, coherence=0.3770
# ✅ no_below=15, no_above=0.5, topics=45, dict_size=21998, coherence=0.3718
#    no_below  no_above  num_topics  dictionary_size  coherence
# 0        15       0.5          30            21998   0.387806
# 1        15       0.5          35            21998   0.378229
# 2        15       0.5          40            21998   0.376996
# 3        15       0.5          45            21998   0.371838
# 🏆 Best dictionary + topic combination:
# no_below=15.0, no_above=0.5, num_topics=30.0, dict_size=21998.0, coherence=0.3878
